# %%
def gender_features(word):
    return {'last_letter' :word[-1]}

# %%
gender_features('Siddharth')
# Out:
# {'last_letter': 'h'}

# %%
from nltk.corpus import names

# %%
names.words()
# Out:
# ['Abagael',
#  'Abagail',
#  'Abbe',
#  'Abbey',
#  'Abbi',
#  'Abbie',
#  'Abby',
#  'Abigael',
#  'Abigail',
#  'Abigale',
#  'Abra',
#  'Acacia',
#  'Ada',
#  'Adah',
#  'Adaline',
#  'Adara',
#  'Addie',
#  'Addis',
#  'Adel',
#  'Adela',
#  'Adelaide',
#  'Adele',
#  'Adelice',
#  'Adelina',
#  'Adelind',
#  'Adeline',
#  'Adella',
#  'Adelle',
#  'Adena',
#  'Adey',
#  'Adi',
#  'Adiana',
#  'Adina',
#  'Adora',
#  'Adore',
#  'Adoree',
#  'Adorne',
#  'Adrea',
#  'Adria',
#  'Adriaens',
#  'Adrian',
#  'Adriana',
#  'Adriane',
#  'Adrianna',
#  'Adrianne',
#  'Adrien',
#  'Adriena',
#  'Adrienne',
#  'Aeriel',
#  'Aeriela',
#  'Aeriell',
#  'Ag',
#  'Agace',
#  'Agata',
#  'Agatha',
#  'Agathe',
#  'Aggi',
#  'Aggie',
#  'Aggy',
#  'Agna',
#  'Agnella',
#  'Agnes',
#  'Agnese',
#  'Agnesse',
#  'Agneta',
#  'Agnola',
#  'Agretha',
#  'Aida',
#  'Aidan',
#  'Aigneis',
#  'Aila',
#  'Aile',
#  'Ailee',
#  'Aileen',
#  'Ailene',
#  'Ailey',
#  'Aili',
#  'Ailina',
#  'Ailyn',
# ...

# %%
print(len(names.words()))
# Out:
# 7944

# %%
labelled_names = [(name, 'male') for name in names.words('male.txt')] + [(name, 'female') for name in names.words('female.txt')]

# %%
import random
random.shuffle(labelled_names)
feature_sets = [(gender_features(n), gender) for (n, gender) in
labelled_names]
train_set, test_set = feature_sets[:5000], feature_sets[2000:]
import nltk
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
feature_sets = [(gender_features(n), gender) for (n, gender) in labelled_names]

# %%
train_set, test_set = feature_sets [:2000], feature_sets[5000:]

# %%
import nltk
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
classifier.classify(gender_features("Sai Siddharth"))
# Out:
# 'male'

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.7622282608695652

# %%
import random
random.shuffle(labelled_names)

# %%
import nltk
f=open('tweets1.txt','r')

# %%
text=f.read()
text1=text.split()
text2=nltk.Text(text1)

# %%
text2.concordance("in")
# Out:
# Displaying 25 of 145 matches:
# y Zoom. The rumors were true Festmob. In The Signal premiere. Lotsa buyers. Go
#  getting ready for work going to work in vista training, this is boring just c
# n office 2007 module i have to get up in 6 hours to drive my sister so i am go
# an office 2007 test and got 100% i am in vista training, yeah another day of i
# h extra caramel and a shot of vanilla In shaw looking for family Holy holy hol
# w for elective 1....audio 101 Waiting in longggggggggggg line for food, the on
# NEGATIVE SPACE....People sqeuazing me in at work, wow i haven't updated in a w
#  me in at work, wow i haven't updated in a while...oops! Discovering twitter i
# n a while...oops! Discovering twitter in a purple sofa... Why isn't Wii releas
# purple sofa... Why isn't Wii released in Singapore yet?! surfing the net playi
# sans pillow, camera crack'd, feathers in hair, copters o'erhead. Here and not
# ...

# %%
from urllib import request

# %%
url="https://www.gutenberg.org/cache/epub/7452/pg7452.txt"

# %%
response=request.urlopen(url)

# %%
raw = response.read().decode('utf8')

# %%
type(raw)
len(raw)
str
raw[:75]
# Out:
# ''

# %%
from nltk.tokenize import word_tokenize
tokens = word_tokenize(raw)
type(tokens)
# Out:
# list
